# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

import xanespy as xp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
datafile = xp.sxstm.SxstmDataFile('sxstm-data-4idc/XGSS_UIC_JC_475v_60c_001_001_001.3ds')
df = datafile.dataframe()
print(len(df))
# Out:
# 300

# %%
df.plot(y='Z (m)')
df.plot(y='Current (A)')
df.median()
# Out:
# Bias calc (V)                 1.000000e+00
# Current (A)                  -8.071288e-10
# LIA Tip Ch1 (V)               2.122244e-01
# LIA Tip Ch2 (V)              -4.108731e-01
# LIA Sample Ch1 (V)            1.472892e-01
# LIA Gold Shielding Ch1 (V)    3.945652e-02
# LIA topo Ch1 (V)              3.877008e-01
# Gold Shielding (V)           -2.479907e-02
# Flux (V)                      4.213902e-01
# Bias (V)                      1.000000e+00
# Output 2 (V)                  0.000000e+00
# Output 3 (V)                  0.000000e+00
# Output 4 (V)                  0.000000e+00
# X (m)                         3.153239e-06
# Y (m)                        -9.195163e-07
# Z (m)                        -3.280919e-07
# dtype: float64

# %%
df
# Out:
#      Bias calc (V)   Current (A)  LIA Tip Ch1 (V)  LIA Tip Ch2 (V)  \
# 0              1.0 -8.635014e-10         0.012604        -0.392287
# 1              1.0 -8.504188e-10         0.013169        -0.391634
# 2              1.0 -8.383399e-10         0.013921        -0.391067
# 3              1.0 -8.264969e-10         0.029534        -0.390546
# 4              1.0 -8.089909e-10         0.049105        -0.390085
# 5              1.0 -7.868572e-10         0.060374        -0.389653
# 6              1.0 -7.667543e-10         0.066295        -0.389388
# 7              1.0 -7.594679e-10         0.069445        -0.388942
# 8              1.0 -7.703084e-10         0.071194        -0.388895
# 9              1.0 -7.948359e-10         0.072102        -0.388994
# 10             1.0 -8.205251e-10         0.073604        -0.388998
# 11             1.0 -8.243402e-10         0.089580        -0.388689
# 12             1.0 -8.068670e-10         0.106070        -0.388545
# ...
